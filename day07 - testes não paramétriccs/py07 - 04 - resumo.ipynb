# %% [markdown]
# ## Resumo de testes de hipótese

# %% [markdown]
# ### 📌 Testes de Hipótese sempre:
#
# 1. Utiliza um teste estatístco
# 2. Calcula sua significâcia (pvalor >= ou < nível_significância)
# 3. E decide se H0 é rejeitada ou não:
#    - H0 não rejeita, pvalor >= nível_significância ~ não há alterações
#    - H0 rejeitada, pvalor < nível_significância, há significância ~ houve alguma alteração
#
#
# **Para isto** antes de rodar o teste:
#   - Temos que escolher a estatistica correta
#   - Temos que definir a Hipótese Nula
#   - Temos que ver se os dados são bem comportados e eventualmente limpá-los (outliers, nan ...)
#   - Temos que definir o nível_significância, usualmente 0.05.

# %% [markdown]
# ### 🎯 Porque Python?
#
# Como se pode ver há várias restrições para se usar uma estatística e seu teste de hipótese:
#
#     1. Conhecer o tipo de variável
#     2. Número amostral
#     3. Outliers podem gerar viés (bias)
#     4. As premissas básicas de cada estatística
#     5. Escolha correta do teste de hipótese:
#       1. Paramétrico
#       2. Não-paramétrico
#     7. A interpretação e crítica dos resulados, estatisticamente
#     8. A interpretação de volta ao modelo científico, tecnológico, administrativo ou comercial usado

# %% [markdown]
# ### 🧪 Não tenha medo é muito fácil na prática, mas ....
#
# **Na prática** `usualmente` usando scipy o teste é chamado da seguinte forma:
#
# stat, pval = stats.<nome do método>(parâmetros)
#
# ### Exemplo
#
# import scikit_posthocs as sp
#
# sp.posthoc_dunn(df, val_col='val', group_col='grupo', p_adjust='bonferroni')
#
# **Parâmetros**:
#
#   - df: um dataframe
#   - val_col: a coluna com valores
#   - group_col: a coluna com nomes dos grupos
#   - p_adjust: qual o método de correção
#
# 📊 Cuidado com as linguagens e pacotes
#
# Alguns parâmetros têm default, e algumas vezes você não pode utilizá-lo. Logo, apenas rodar dados obtidos sem saber o que está fazendo é um crime, pode gerar erros. Na dúvida consulte alguém mais experiente.
#
#
# ### 🧪 Retorno usual: stats e pval
#
# Usualmente, o teste retorna `stats` e `pval`
#
#
# > stats: corresponde ao valor da estatística
# > pval: p-value ou p-valor para se comparar com o nível de significância
#
#
# 🎯 Mas, um dado teste pode retornar mais variáveis e eventualmete tabelas ou pointers para tabelas - tipo result.summary()

# %% [markdown]
# ### 📌 Testes de Paramétricos
#
# > A seguir vamos explicar `na prática` como se raciocina para se utilizar testes de hipóteses e distribuições normais.
# > Vamos utilizar cortes de N amosral como 10 e 30, mas eles não são rígidos, você deve estudar seus dados
#
# **Se distribuição normal**
#
#   - Na prática podemos usar um limiar de N amostral = 30:
#     - Com N na faixa entre \[10,30], pode-se usar paramétrico se:
#       - distribuição aproximadamente normal
#       - sem outliers severos
#       - testes como: t-student e Dunnett
#     - Com N < 10:
#       - Não é recomendado usar testes paramétricos
#     - Com N >= 30:
#       - Amostras maiores tornam os testes paramétricos mais robustos.
#       - Ou a distribuição é normal ou invoca-se o TCL
#       - Se invocar TCL:
#          - Sem outliers
#          - Sem assimetrias
#          - Sem heterocedasticidade (desvio padrões que aumentam com o crescimento da média)
#   - Em qualquer limiar é recomendado testar com o teste paramétrico e seu dual não-paramétrico

# %% [markdown]
# ### 📌 Testes Não-Paramétricos
#
# Na prática, mas sempre analise bem seud dados, podemos recomendar
#
# **Usualmente**:
#   - Quando a distribuição não é normalmente distribuida:
#     - Há outliers que não se pode remover
#     - Há assimetrias fortes (grandes caudas para um lado somente)
#   - Quando N < 30 (Receita prática, pode flexibilizar)
#     - Entre \[10, 30] use teste-t de Welch
#     - N < 10 use testes paramétricos
#
#
# 🎯 Não tenha medo de usar um teste **não-paramétrico**
#
#   - Ele é tão simples de usar como o paramétrico
#   - Usualmente retorna stats e pval
#   - Na dúvida, rode os dois tipos de testes:
#
# |  Paramétrico   |   Não-Paramétrico |  Resultado |
# |----------------|-------------------|------------|
# |  Não Rejeita H0     |   Não Rejeita H0 |  Não Rejeita H0 |
# |  Não Rejeita H0     |   Rejeita H0 | Não Rejeita H0  |
# |  Rejeita H0     |   Não Rejeita H0 | Não Rejeitac H0 |
# |  Rejeita H0     |   Rejeita H0 |  Rejeita H0 |

# %% [markdown]
# ### 🔎 Roteiro prático que requer a crítica do pesquisador
#
#   - 1 variável numérica, 2 grupos independentes:
#     - Dados normais e N amostral grande: Z-test
#     - Dados aproximadamente normais → t-test
#     - Dados assimétricos/outliers fortes → Mann–Whitney
#   - 1 variável numérica, >2 grupos:
#     - Normal → ANOVA
#     - Não normal → Kruskal–Wallis
#   - Variável categórica:
#     - Qui-quadrado
#   - Estudo qualitativo (não mostramos aqui):
#     - Transformar a informação qualitativa em quantitativa:
#     - Exemplo:
#       - Fraco, Regular e Bom --> 0, 1, 2

# %% [markdown]
# ### 📌 Apresentação final dos resultados
#
#   - Descreva a estatística escolhida e o porquê:
#     - Use o teste adequado às premissas e ao desenho experimental.
#   - Apresente os p-valores, mas não é suficiente:
#   - Sempre apresente:
#     - Número amostral
#     - Tamanho de efeito
#     - Intervalo de confiança
#   - Em caso de múltiplas comparações, sempre corrija o p-valor:
#     - FDR: mais usado
#     - Bonferroni: muito ortodoxo, por vezes bom para N pequenos
