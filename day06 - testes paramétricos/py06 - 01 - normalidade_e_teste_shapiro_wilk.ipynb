# %% [markdown]
# ### A distribuição Normal (de Moivre ou Gaussiana)
# #### Pode ser estimada através de 2 parâmetros:
#   - média
#   - desvio padrão

# %%
# função numérica do python: numpy
import numpy as np

# função estatística do python: scipy
from scipy import stats
from scipy.stats import gaussian_kde

import seaborn as sns

# função gráfica: matplotlib (há outras como seaborn e plotly)
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Variando medias e desvios padrões

# %%
mu_params = [-1, 0, 1]
sd_params = [0.5, 1, 1.5]

x = np.linspace(-7, 7, 100)
f, ax = plt.subplots(len(mu_params), len(sd_params), sharex=True, sharey=True, figsize=(12,8))

for i in range(3):
    for j in range(3):
        MU = mu_params[i]
        SSD = sd_params[j]

        y = stats.norm(MU, SSD).pdf(x)
        label = f"MU = {MU:.1f} SSD={SSD:.1f}"

        ax[i,j].plot(x, y)
        ax[i,j].plot(0, 0, label=label, alpha=0)
        ax[i,j].legend(loc='upper right', fontsize=12);

ax[2,1].set_xlabel('$x$', fontsize=16);
ax[1,0].set_ylabel('$pdf(x)$', fontsize=16);

plt.tight_layout()

# %% [markdown]
# ### A distribuição Z é uma normal com media=0 e sigma=1

# %%
N=500
MU = 0
SSD = 1

# random normal - stats.norm. random variates
y = stats.norm.rvs(loc=MU,scale=SSD,size=N)

# plot histogram
ret = plt.hist(y, bins=30, density=True)
perc, bins, patches = ret

# stats.norm.pdf - probabilistic density function
yfit = stats.norm(MU, SSD).pdf(bins)
l = plt.plot(bins, yfit, 'r-.', lw=2)

# kernel gaussiano
# aproximar os dados a uma curva próxima a uma gaussiana ~ smooth (arredondamento suave)
kde = gaussian_kde(y)
seqx = np.linspace(y.min(), y.max(), 400)
y_kde = kde(seqx)
plt.plot(seqx, y_kde, 'b--', lw=2)

plt.grid()

# %%
MU = 0
SSD = 1

y = stats.norm.rvs(loc=MU,scale=SSD,size=500)

sns.histplot(y, bins=30, stat="density", kde=True)

yfit = stats.norm(MU, SSD).pdf(bins)
l = plt.plot(bins, yfit, 'r--', lw=2)

plt.grid()

# %%
sns.histplot(y, bins=30, stat="density", kde=True);

# %% [markdown]
# ### O que acontece se amostrarmos 10 números

# %%
MU = 0
SSD = 1
N=10

y = stats.norm.rvs(loc=MU,scale=SSD,size=N)
y

# %%
sns.histplot(y, bins=10, stat="density", kde=True);

# %% [markdown]
# ### Teste de normalidade de Shapiro-Wilk - SWT SW-test

# %%
stat, pvalue = stats.shapiro(y)
print(stat, pvalue)

if pvalue >= 0.05:
    print("H0: Segundo SWT estes valores parecem se aproximar de uma distribuição normal")
else:
    print("Ha: Segundo SWT estes valores NÃO se aproximam de uma distribuição normal")

# %%
# Shapiro-Wilk test com matplotlib
def mostre_calcule_SWT(y, bins=30):
    stat, pvalue = stats.shapiro(y)

    ret = plt.hist(y, bins=bins, density=True, label='hist')
    n, bins, patches = ret

    mu = np.mean(y)
    ssd = np.std(y)

    mini = np.min(y)
    maxi = np.max(y)

    seqx = np.linspace(mini, maxi, 400)

    yfit = stats.norm.pdf(seqx, mu, ssd)
    l = plt.plot(seqx, yfit, 'r--', linewidth=2, label='fit')

    y_kde = kde(seqx)
    plt.plot(seqx, y_kde, 'b--', lw=2, label='kde')

    title = f"Distriubição randômica - {len(y)} amostras"
    plt.grid()
    plt.legend()
    plt.title(title);

    if pvalue >= 0.05:
        stri = "H0 aceita - estatisticamente distribuições similares."
        stri += f"\nSegundo o teste de Shapiro-Wilk esta distribuição se aproxima a uma normal, pvalue={pvalue:.2e}"
    else:
        stri = "H0 rejeitada - estatisticamente distribuições distintas."
        stri += f"\nSegundo o teste de Shapiro-Wilk esta distribuição não se aproxima a uma normal, pvalue={pvalue:.2e}"

    return ret, stat, pvalue, stri

# %%
# Shapiro-Wilk test com seaborn - melhor
def mostre_calcule_SWT_sns(y, bins=30):
    stat, pvalue = stats.shapiro(y)

    # o histplot
    #         gera uma distribuição se stat="density"
    #         gera a curva KDE se kde=True
    sns.histplot(y, bins=30, stat="density", kde=True, label='hist+kde')

    mu = np.mean(y)
    ssd = np.std(y)

    mini = np.min(y)
    maxi = np.max(y)

    seqx = np.linspace(mini, maxi, 400)

    yfit = stats.norm.pdf(seqx, mu, ssd)
    l = plt.plot(seqx, yfit, 'r--', linewidth=2, label='fit')

    title = f"Distriubição randômica - {len(y)} amostras"
    plt.grid()
    plt.legend()
    plt.title(title);

    if pvalue >= 0.05:
        stri = "H0 aceita - estatisticamente distribuições similares."
        stri += f"\nSegundo o teste de Shapiro-Wilk esta distribuição se aproxima a uma normal, pvalue={pvalue:.2e}"
    else:
        stri = "H0 rejeitada - estatisticamente distribuições distintas."
        stri += f"\nSegundo o teste de Shapiro-Wilk esta distribuição não se aproxima a uma normal, pvalue={pvalue:.2e}"

    return stat, pvalue, stri

# %% [markdown]
# ### N=5 - absurdo! muito pequeno

# %%
MU = 0
SSD = 1
N=5

y = stats.norm.rvs(loc=MU,scale=SSD,size=N)
ret, stat, pvalue, stri = mostre_calcule_SWT(y)

print(stri, '\n')

# %%
ret

# %%
MU = 0
SSD = 1
N=8

y = stats.norm.rvs(loc=MU,scale=SSD,size=N)
stat, pvalue, stri = mostre_calcule_SWT_sns(y)

print(stri, '\n')

# %% [markdown]
# ### iid - independente e identicamente distribuída
#
# Quando jogamos dados, moedas ou valores reais ou por simulação, dizemos que se não há correlação entre 2 jogas de N amostras, as duas jogadas são iid - independente e identicamente distribuídas.

# %% [markdown]
# ### Teorema Central do Limite (TCL)
#
# O Teorema Central do Limite afirma que `a distribuição das médias amostrais aproxima-se de uma distribuição normal à medida que o tamanho da amostra ($N_{amostral}$) aumenta`, **`independentemente da distribuição original dos dados da população`**.
#
# Fundamental na estatística, ele permite realizar inferências (como intervalos de confiança) mesmo com amostras pequenas (geralmente $N_{amostral}$ < 30), mesmo sem saber qual a distribuição da população (discreta ou contínua, e qual)
#
# https://en.wikipedia.org/wiki/Central_limit_theorem

# %% [markdown]
# ### Como uma amostra com N = 5 pode se aproximar de uma normal?
#
# O Teorema Central do Limite diz:
#   - A distribuição da valor esperado central tende à normal quando N → ∞
#
# ❌ O TCL não diz:
#   - que os dados ficam normais
#   - que N pequeno funciona
#   - que N = 5 *já é suficiente para analisarmos diferenças estatísticas*
#
# 👉 Para N = 5:
#   - a distribuição da média herda a assimetria e curtose da população
#   - a média, por chance, pode se aproximar da média amostral para N grandes
#   - o desvio padrão, normalmente, é subestimado quanto ao desvio padrão amostral

# %% [markdown]
# ### Normalidade não é inferida com N pequeno — é assumida ou não.
#
#   - ssumir normalidade para números amostraais pequenos (N < 30) é sua responasabilidade.
#   - é impossível a estatística afirmar que a distribuição é normal quando N é pequeno.

# %% [markdown]
# ### O correto:
#   - N pequeno
#     - teste de Shaprio-Wilk
#         - se Ok - forçado/assumido --> t-test
#           - pareado
#           - não pareado
#         - se NOk --> teste não parmétricos (rank-tests)
#           - Se grupos independentes -> teste U de Mann-Whitney
#           - Se grupos pareados -> test de Wilcoxon signed-rank

# %% [markdown]
# ### Teste U de Mann-Whitney
#
# O teste U de Mann-Whitney é um método estatístico não paramétrico utilizado para comparar se existem diferenças entre duas amostras independentes quando os dados não seguem uma distribuição normal ou são ordinais. Ele é considerado o equivalente não paramétrico do teste t de Student para amostras independentes.

# %% [markdown]
# ### Teste de Wilcoxon signed-rank (teste de postos sinalizados de Wilcoxon)
#
# O teste de Wilcoxon signed-rank (teste de postos sinalizados de Wilcoxon) é um teste estatístico não paramétrico usado para comparar duas amostras pareadas (ex: antes e depois) ou uma amostra com um valor de referência, substituindo o teste t pareado quando os dados não seguem uma distribuição normal. Ele analisa tanto o sinal quanto a magnitude das diferenças entre as observações.

# %% [markdown]
# ### O que acontece se amostrarmos 100 vezes

# %%
MU = 0
SSD = 1
N=100

y = stats.norm.rvs(loc=MU,scale=SSD,size=N)
ret_graph, stat, pvalue, stri = mostre_calcule_SWT(y)

print(stri, '\n')

# %%
stat, pvalue, stri = mostre_calcule_SWT_sns(y)

print(stri, '\n')

# %% [markdown]
# ### O que acontece se amostrarmos 1000 números

# %%
MU = 0
SSD = 1
N=1000

y = stats.norm.rvs(loc=MU,scale=SSD,size=N)
ret_graph, stat, pvalue, stri = mostre_calcule_SWT(y)

print(stri, '\n')

# %%
stat, pvalue, stri = mostre_calcule_SWT_sns(y)

print(stri, '\n')

# %% [markdown]
# ### Usando a função numpy arange para criar uma lista de 0 a 19 (20 elementos)

# %%
np.arange(0, 20)

# %%
y = np.arange(0, 200)
ret_graph, stat, pvalue, stri = mostre_calcule_SWT(y)

print(stri, '\n')

# %%
stat, pvalue, stri = mostre_calcule_SWT_sns(y)

print(stri, '\n')

# %%
N=20

y =  [1]*N + [3]*N + [5]*N + [7]*N + [9]*N
np.array(y)

# %%
ret_graph, stat, pvalue, stri = mostre_calcule_SWT(y)

print(stri, '\n')

# %%
stat, pvalue, stri = mostre_calcule_SWT_sns(y)

print(stri, '\n')
