# %%
from scipy import stats
import numpy as np
import pandas as pd

from statistics import mode

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Distribuição Normal (Gaussiana)
#
#   - Descoberta Moivre
#   - Utilizada a primeira vez por Gauss
#
# **Probabilistic Density Function**
#
# <font size="6">Normal PDF = f(x) = $\frac{1}{\sqrt{2\pi*SSD^2}}*\exp{(\frac{-(x-<x>)^2}{2*SSD^2})}$</font>
#
# https://en.wikipedia.org/wiki/Normal_distribution

# %% [markdown]
# #### Analisando distribuição normal com seaborn
#   - Distribuição contínua
#   - Logo, utiliza variáveis continuas, exemplo
#     - altura e peso de pessoas
#     - temperatura em pessoas saudáveis
#     - densidade de um composto
#     - média de acidentes numa via !!!

# %% [markdown]
# #### Critique
#   - Distribuição contínua e normal
#     - altura e peso de pessoas
#     - média de acidentes numa via !!!
#
#
#   - Espera a distribuição a normal e ela não ocorre:
#     - Estratitifca subpopulações (masc/fem peso)
#     - Log-Normal --> fenomenomo exponencial --> log() --> Normal (ômicas)
#
# As distribuições acima podem divergir da normal?

# %% [markdown]
# ### Simulando uma distribuição normal
#
# #### Amostrando com np.random.normal()
#
#  - media - mean - loc
#  - desvio padrão - scale
#
# ### Distriuição normal:
#   - media ~ mdiana ~ moda
#
# Logo, se aparecer bi-modalidade (2 picos):
#   - estratitifcar em 2 conjuntso de dados (masc/fem, p.ex.)
#   - cada um destes conjuntos --> Normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
#
# Português:
# https://numpy.org/pt/

# %%
# simulação de altura
MU = 170  # cm
SSD = 12
N = 10000

#      np.random.normal(loc, scale, nsize)
#      np.random.normal(media, SD, nvezes)
vals = np.random.normal(MU, SSD, N)

#- mu = media calculada
mu = np.mean(vals)
ssd = np.std(vals)
med = np.median(vals)
mod = mode(vals)

title = f"Uma distribuição normal media={MU}({SSD}) cm e com {N} valores"
# \n --> carriage return - mudar de linha
title += f"\namosral -> media={mu:.2f} mediana={med:.2f} moda={mod:.2f} além de SSD={ssd:.2f}"

# distplot do seaborn = histograma
ax = sns.displot(vals, height=4, aspect=2)
plt.title(title);

# %% [markdown]
# ### estudos acima de media + 2*SD e abaixo media - 2*SD
#
#   - acima = 170 + 2*12 = 194 cm
#     - acima de 200 (media + 2*SD) <> area 2.5% == p-valor = 2.5%
#   - abaixo = 170 - 2*12 = 146 cm
#     - acima de 200 (media - 2*SD) <> area 2.5% == p-valor = 2.5%

# %%
sns.displot(vals, height=4, aspect=2)

#-- vertical line
plt.axvline(mu, color='red')
#- MU = media definida e colocada na maquina np.random.normal(MU ....)
plt.axvline(med, color='orange')
plt.axvline(mod, color='black')

#- dispersão: Desvio Padrão
plt.axvline(mu+ssd, color='brown')
plt.axvline(mu-ssd, color='brown')

plt.axvline(mu+2*ssd, color='darkcyan')
plt.axvline(mu-2*ssd, color='darkcyan')


plt.title(title);

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(3, 1, figsize=(14,10), sharex=True)
sns.despine(left=True)

#------------- eixo 0 - pdf -------------------
ax=axes[0]
ax = sns.histplot(vals, kde=False, color='blue', ax=ax)
ax.set_ylabel("Contagem")
ax.set_title("Gráfico de Frequência - dados uniformemente amostrados")

ax.set_title(title)

ax.axvline(mu, color='red')
ax.axvline(med, color='orange')
ax.axvline(mu+ssd, color='brown')
ax.axvline(mu-ssd, color='brown')

# Add annotation
outlier_inf = 130
ax.annotate(
    'Outliers Inf',
    xy=(outlier_inf, 0),  # Point to annotate (arrow tip)
    xytext=(outlier_inf, 200),  # Position of the text
    arrowprops=dict(facecolor='black', shrink=0.05), # Arrow properties
    horizontalalignment='left', # Text alignment
    verticalalignment='center' # Text alignment
)

# Add annotation
outlier_sup = 210
ax.annotate(
    'Outliers Sup',
    xy=(outlier_sup, 0),  # Point to annotate (arrow tip)
    xytext=(outlier_sup, 200),  # Position of the text
    arrowprops=dict(facecolor='black', shrink=0.05), # Arrow properties
    horizontalalignment='left', # Text alignment
    verticalalignment='center' # Text alignment
)

#------------- eixo 1 - boxplot -------------------
ax=axes[1]
ax = sns.boxplot(x=vals, color='lightblue', ax=ax)
ax.set_title("Boxplot - q1 <> mu-SSD e q2 <> mu+SSD")

ax.axvline(mu, color='red')
ax.axvline(med, color='orange')
ax.axvline(mu+ssd, color='brown')
ax.axvline(mu-ssd, color='brown')

#------------- eixo2 - cumulativa -------------------
ax=axes[2]
# ecdf - cumulative
sns.ecdfplot(x=vals, color="steelblue", ax=ax)

ax.axvline(mu, color='red')
ax.axvline(med, color='orange')
ax.axvline(mu+ssd, color='brown')
ax.axvline(mu-ssd, color='brown')

ax.set_title('cumulativa');

# %% [markdown]
# ### Média e Desvio Padrão Amostral calculados dos valores obtidos pela máquina randômica

# %%
print("Na distribuição normal a média, mediana e moda são próximas ou iguais")
f"média {mu:.3f} || mediana {med:.3f} || moda {mod:.3f} "

# %% [markdown]
# ### A distribuição normal é paramétrica
# #### Parâmestros (média e desvio padrão) ou (media e variância)

# %% [markdown]
# ### Calculando os parâmetros média e desvio padrão e desenhando o gráfico da distribuição Normal

# %% [markdown]
# #### Valores de x vão de 'menos infinito' a 'mais infinito'
#
#   - menos infinito - próximo percentil muito baixo ~ 0.001
#   - mais infinito - próximo percentil muito alto ~ 0.999

# %%
MU, SSD

# %%
# alguém muito baixo
# ppf = percent point function (PPF)
float(np.round(stats.norm.ppf(0.001, MU, SSD),3))

# %%
# alguém muito alto
float(np.round(stats.norm.ppf(0.999, MU, SSD),3))

# %%
# linspace -> linha de inf até sup com N divisões

val_inf = stats.norm.ppf(0.01, MU, SSD)
val_sup = stats.norm.ppf(0.99, MU, SSD)

print(f"{val_inf:.2f} - até - {val_sup:.2f}")

# lista desde val_inf até val_sup com N (10000) divisões
seqx = np.linspace(val_inf, val_sup, N)
len(seqx), seqx[:4], seqx[-4:]

# %% [markdown]
# #### Simulando os valores da distribuição desde inf até sup (seqx)
#
#   - já temos os pontos em x --> seqx
#   - para cada x podemos calcular a PDF --> probabilidade --> e desenhar a curva
#   - para isto uso: **stats.norm.pdf()** --> probalistica density function

# %%
# np.array -> lista de PDFs
normal_pdf = stats.norm.pdf(seqx, loc=MU, scale=SSD)
len(normal_pdf), N

# %% [markdown]
# #### Frequência
#   - repare rug=True, mostra um tapete de pontos amostrados

# %%
g = sns.displot(x=vals, kind='hist', rug=True,
                height=6, aspect=2, color="steelblue")

plt.axvline(mu, color='red')
#- MU = media definida e colocada na maquina np.random.normal(MU ....)
plt.axvline(med, color='orange')

#- dispersão: Desvio Padrão
plt.axvline(mu+ssd, color='brown')
plt.axvline(mu-ssd, color='brown')
plt.title('Gráfico de frequência usando sns.displot e rug=True');

# %%
N, len(vals)

# %%
# 1 x 1 --> 1 plot somente
fig, ax = plt.subplots(figsize=(12, 6))

sns.set_theme(style="darkgrid")

# density --> soma(pis)=1
ax = sns.histplot(x=vals, stat='density',  color="steelblue", ax=ax)
#--- fitando a distribuição normal com mu e SSD
#---                          Percent Point Function (PPF)
val_inf = stats.norm.ppf(0.001, MU, SSD)
val_sup = stats.norm.ppf(0.999, MU, SSD)
seqx = np.linspace(val_inf, val_sup, N)

### calc as probalilidades de cada ponto em seqx
normal_pdf = stats.norm.pdf(seqx, loc=MU, scale=SSD)

# qdo função continua: distribuiçao regida por probability density function (pdf)
# ax.plot(seqx, normal_pdf, color="navy", linewidth=2)
sns.lineplot(x=seqx, y=normal_pdf, color='navy', ax=ax)

mu = np.mean(vals)
med = np.median(vals)
ssd = np.std(vals)

ax.vlines(mu, 0, 0.036, color = 'black');
ax.hlines(0.02, mu, mu+ssd, color = 'red');

title = F'Distribuição normal com média = {MU} e desvio padrão = {SSD}'
ax.set_title(title);

# %% [markdown]
# ### Variando médias e desvios padrões

# %%
mu_params = [-1, 0, 1]
sd_params = [0.5, 1, 1.5]

x = np.linspace(-6, 6, 100)
f, ax = plt.subplots(len(mu_params), len(sd_params), sharex=True, sharey=True, figsize=(12,8))

for i in range(3):
    for j in range(3):
        mu = mu_params[i]
        sd = sd_params[j]
        y = stats.norm(mu, sd).pdf(x)
        ax[i,j].plot(x, y)
        ax[i,j].plot(0, 0, label=f"mu = {mu:3.2f}\nSSD = {sd:3.2f}", alpha=0)
        ax[i,j].legend(fontsize=12);

ax[2,1].set_xlabel('$x$', fontsize=16);
ax[1,0].set_ylabel('$pdf(x)$', fontsize=16);

plt.tight_layout()

# %% [markdown]
# ### Distância entre 2 distribuições - preparação para o teste-t

# %%
MU_list = [1, 3]
SD_list = [0.3, 0.8]
N = 1000

samp1 = np.random.normal(MU_list[0], SD_list[0], N)
samp2 = np.random.normal(MU_list[1], SD_list[1], N)

#-- dataframe - distribuição 1 coluna dist1 e ...
df = pd.DataFrame([samp1, samp2]).T
df.columns=['dist1', 'dist2']
df.head(7)

# %% [markdown]
# ### Duas distribuições sobrepostas

# %%
colors = ['blue', 'red']

fig, ax = plt.subplots(figsize=(12, 6))
# fig = plt.figure(figsize=(12, 6))


for i in range(2):
    # histogram
    col = f'dist{(i+1)}'
    sns.histplot(df[col], stat='density', color=colors[i], fill=True, alpha=0.25, label=col, ax=ax)
    # rug
    sns.rugplot(df[f'dist{i+1}'], color=colors[i], alpha=0.1, height=0.04, ax=ax)

mu1 = df.dist1.mean()
sd1 = df.dist1.std()

mu2 = df.dist2.mean()
sd2 = df.dist2.std()


title  =   "Distribuição 1 (vermelha) tem média = %.2f e SSD = %.2f"%(mu1, sd1)
title += "\nDistribuição 2 (azul) tem média = %.2f e SSD = %.2f"%(mu2, sd2)
plt.legend()
plt.title(title);

# %% [markdown]
# ### Pontos em samp2 além de 2 SSD == 2

# %%
lista = samp2
lista = np.sort(lista)

lista[:5], lista[-5:]

# %%
MU1 = MU_list[0]
SSD1 = SD_list[0]

MU2 = MU_list[1]
SSD2 = SD_list[1]

cutoff = (MU2+2*SSD2)
cutoff

# %%
lista_sig = lista[lista > cutoff]
len(lista_sig), lista_sig[:5]

# %%
cutoff = (MU2-2*SSD2)
print(cutoff)

lista_sig = lista[lista < cutoff]
len(lista_sig), lista_sig[-5:]

# %% [markdown]
# ### Coeficiente de variação
#
# <font size="5">$CV = \frac{SD}{media}$</font>
#
# ### Tamanho do efeito (effect size)
#
# <font size="5">$ES = \frac{media_1 - media_2}{SD_{pool}}$</font>
#
# https://en.wikipedia.org/wiki/Effect_size
#
#
# ### Distância não padronizada
#
# <font size="5">$diff = media_1 - media_2$</font>
#
#
# ### Markdown
#
# https://csrgxtu.github.io/2015/03/20/Writing-Mathematic-Fomulars-in-Markdown/
#
# https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html

# %%
f"MU1 = {MU1:.1f}  e SSD1 = {SSD1:.1f}"

# %%
f"MU2 = {MU2:.1f}  e SSD2 = {SSD2:.1f}"

# %%
CV1 = SSD1/MU1
CV2 = SSD2/MU2

f"CV1 = {100*CV1:.1f}%  e CV2 = {100*CV2:.1f}%"

# %% [markdown]
# ### Tamanho de Efeito de Cohen

# %%
# desvio padrão conjunto

import math

N1 = N
N2 = N

SDpool = math.sqrt( ((N1-1)*SSD1**2 + (N2-1)*SSD2**2) / (N1+N2-2) )

f"SSD1 = {SSD1:.2f}, SSD2 = {SSD2:.2f} e SDpool = {SDpool:.2f}"

# %%
ES = (MU2 - MU1) / SDpool

# effect size - tamanho de efeito
f"MU2 = {MU2:.2f}, MU1 = {MU1:.2f} e SDpool = {SDpool:.2f} -> ES = {ES:.2f}"

# %% [markdown]
# 🧠 Qual devo usar? (regra prática)
#
# | Situação	|  Método |
# |---------------|------------------|
# | SDs parecidos	| Cohen’s d (pooled) |
# | SDs bem diferentes + controle	| Glass’s Δ |
# | Amostra pequena	| Hedges’ g |
# | Meta-análise	| Hedges’ g |

# %% [markdown]
# ### Spoiler - teste de hipótese
# #### Em breve teste de hipótese: são as duas distribuições diferentes?

# %%
colors = ['blue', 'red']

fig, ax = plt.subplots(figsize=(12, 6))

for i in range(2):
    col = 'dist%d'%(i+1)
    ax = sns.histplot(x=df[col], stat='density',  color=colors[i], ax=ax)

    val_inf = stats.norm.ppf(0.001, MU_list[i], SD_list[i])
    val_sup = stats.norm.ppf(0.999, MU_list[i], SD_list[i])

    seqx = np.linspace(val_inf, val_sup, 100)
    pdf_norms = stats.norm.pdf(seqx, MU_list[i], SD_list[i])

    sns.lineplot(x=seqx, y=pdf_norms, color=colors[i])

mu1 = df.dist1.mean()
sd1 = df.dist1.std()

mu2 = df.dist2.mean()
sd2 = df.dist2.std()

plt.axvline(x=MU_list[0], ymin=0, ymax=1.4, color='black')
plt.axvline(x=MU_list[0]+SD_list[0], ymin=0, ymax=1.0, color='black', linestyle='--')
plt.axvline(x=MU_list[0]-SD_list[0], ymin=0, ymax=1.0, color='black', linestyle='--')

plt.axvline(x=MU_list[1], ymin=0, ymax=.6, color='black')
plt.axvline(x=MU_list[1]+SD_list[1], ymin=0, ymax=.4, color='black', linestyle='--')
plt.axvline(x=MU_list[1]-SD_list[1], ymin=0, ymax=.4, color='black', linestyle='--')

head_width = 0.05

# nsamp = N*sqrt(SD_list[0]**2/n**2 + SD_list[1]**2/n**2)
n1=N
n2=N

SDpool = math.sqrt( ((n1-1)*sd1**2 + (n2-1)*sd2**2) / (n1+n2-2) )
EffSize = (mu2 - mu1) / SDpool

diff = MU_list[1]-MU_list[0]
xdiff = MU_list[1] - (diff/2)
yarrow = 0.7

sta, pval = stats.ttest_ind(df.dist1, df.dist2)
#text_stat = "t-test statistics = %.2f, p-val = %.2e"%(sta, pval)
text_stat = "estatística t-test = %.2f, p-val = %.2e"%(sta, pval)

plt.arrow(MU_list[0], yarrow, (diff-2*head_width), 0, head_width=head_width, head_length=0.1, fc='k', ec='k')

text = 'ES = %.2f, diff = %.1f, SSD = %.2f'%(EffSize, diff, SDpool)
plt.text(x=(xdiff-.65), y=(yarrow+.1), s=text)
plt.xlabel("values")
plt.ylabel("percentage (%)")

title  =   "Distribuição 1 (azul) tem media (SSD) = %.1f (%.2f) e n = %d amostras"%(mu1, sd1, N)
title += "\nDistribuição 2 (vermelha) tem media (SSD) = %.1f (%.2f) e n = %d amostras"%(mu2, sd2, N)
title += '\n' + text_stat + '\nTamanho do efeito = %.2f'%(EffSize)
plt.title(title);

# %% [markdown]
# ### Criando o eixo x

# %%
seqxs = []
seqx1 = np.linspace(stats.norm.ppf(0.01, MU_list[0], SD_list[0]), stats.norm.ppf(0.99, MU_list[0], SD_list[0]), 100)
seqxs.append(seqx1)
seqx1[:5], seqx1[-10:-1]

# %%
seqx2 = np.linspace(stats.norm.ppf(0.01, MU_list[1], SD_list[1]), stats.norm.ppf(0.99, MU_list[1], SD_list[1]), 100)
seqxs.append(seqx2)
seqx2[:5], seqx2[-10:-1]

# %% [markdown]
# ### Fazendo um stack para o barplot

# %%
df.head(3)

# %%
df1 = pd.DataFrame(df.dist1)
df1['class'] = 'um'
df1.columns = ['val', 'class']

df2 = pd.DataFrame(df.dist2)
df2['class'] = 'dois'
df2.columns = ['val', 'class']

dfa = pd.concat([df1, df2])

len(dfa), len(df1), len(df2)

# %% [markdown]
# ### Barplot/Violinplot invertido

# %%
dfa.head(3)

# %%
dfa.tail(3)

# %%
df.head(2)

# %%
fig = plt.figure(figsize=(6, 6))

cols=["dist1", "dist2"]
sns.boxplot(data=df[cols], palette=['blue', 'red'], saturation=.4)
plt.title("Boxplot");

# %%
fig = plt.figure(figsize=(6, 6))

cols=["dist1", "dist2"]
sns.boxplot(data=df[cols], palette=['blue', 'red'],
            showfliers=False, saturation=.4)

sns.stripplot(data=df[cols],  color="black",
              alpha=0.1, size=4, jitter=True
             )
plt.title("Boxplot");

# %%
fig = plt.figure(figsize=(6, 6))

cols=["dist1", "dist2"]
sns.violinplot(data=df[cols], palette=['blue', 'red'], inner='quart', saturation=.4)
plt.title("Violinplot");

# %%
fig = plt.figure(figsize=(6, 6))

cols=["dist1", "dist2"]
sns.violinplot(data=df[cols], palette=['blue', 'red'], inner='quart', saturation=.4)

sns.stripplot(data=df[cols],  color="black",
              alpha=0.1, size=4, jitter=True
             )

plt.title("Violinplot");
